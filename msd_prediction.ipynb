# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Setting display format to retina in matplotlib to see better quality images.
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# Lines below are just to ignore warnings
import warnings
warnings.filterwarnings('ignore')

from config import username, password
from sqlalchemy import create_engine
import psycopg2

# %%
# Dowanloading original msd dataset
msd_df = pd.read_csv('msd_summary.csv')
msd_df.head()
# Out:
#    song_no  analysis_sample_rate                         audio_md5  \
# 0        1                 22050  aee9820911781c734e7694c5432990ca
# 1        2                 22050  ed222d07c83bac7689d52753610a513a
# 2        3                 22050  96c7104889a128fef84fa469d60e380c
# 3        4                 22050  0f7da84b6b583e3846c7e022fb3a92a2
# 4        5                 22050  228dd6392ad8001b0281f533f34c72fd
#
#    danceability   duration  end_of_fade_in  energy  idx_bars_confidence  \
# 0             0  252.05506           2.049       0                    0
# 1             0  156.55138           0.258       0                    0
# 2             0  138.97098           0.000       0                    0
# 3             0  145.05751           0.000       0                    0
# 4             0  514.29832           0.000       0                    0
#
#    idx_bars_start  idx_beats_confidence  ...  idx_artist_terms  \
# 0               0                     0  ...                 0
# 1               0                     0  ...                 0
# 2               0                     0  ...                 0
# 3               0                     0  ...                 0
# 4               0                     0  ...                 0
#
#    idx_similar_artists                               release  \
# 0                    0                 Monster Ballads X-Mas
# 1                    0                           Karkuteillä
# 2                    0                                Butter
# 3                    0                               De Culo
# 4                    0  Rene Ablaze Presents Winter Sessions
#
#    release_7digitalid  song_hotttnesss             song_id              title  \
# 0              633681         0.542899  SOQMMHC12AB0180CB8       Silent Night
# 1              145266         0.299877  SOVFVAK12A8C1350D9        Tanssi vaan
# 2              625706         0.617871  SOGTUKN12AB017F4F1  No One Could Ever
# 3              199368              NaN  SOBNYVR12A8C13558C      Si Vos Querés
# 4              209038              NaN  SOHSBXH12A8C13B0DF   Tangle Of Aspens
#
#    track_7digitalid  idx_artist_mbtags  year
# 0           7032331                  0  2003
# 1           1514808                  0  1995
# 2           6945353                  0  2006
# 3           2168257                  0  2003
# 4           2264873                  0     0
#
# [5 rows x 54 columns]

# %%
# Basic information of msd_df
msd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 54 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   song_no                         1000000 non-null  int64
#  1   analysis_sample_rate            1000000 non-null  int64
#  2   audio_md5                       1000000 non-null  object
#  3   danceability                    1000000 non-null  int64
#  4   duration                        1000000 non-null  float64
#  5   end_of_fade_in                  1000000 non-null  float64
#  6   energy                          1000000 non-null  int64
#  7   idx_bars_confidence             1000000 non-null  int64
#  8   idx_bars_start                  1000000 non-null  int64
#  9   idx_beats_confidence            1000000 non-null  int64
#  10  idx_beats_start                 1000000 non-null  int64
#  11  idx_sections_confidence         1000000 non-null  int64
#  12  idx_sections_start              1000000 non-null  int64
#  13  idx_segments_confidence         1000000 non-null  int64
#  14  idx_segments_loudness_max       1000000 non-null  int64
#  15  idx_segments_loudness_max_time  1000000 non-null  int64
#  16  idx_segments_loudness_start     1000000 non-null  int64
#  17  idx_segments_pitches            1000000 non-null  int64
#  18  idx_segments_start              1000000 non-null  int64
#  19  idx_segments_timbre             1000000 non-null  int64
#  20  idx_tatums_confidence           1000000 non-null  int64
#  21  idx_tatums_start                1000000 non-null  int64
#  22  key                             1000000 non-null  int64
#  23  key_confidence                  1000000 non-null  float64
#  24  loudness                        1000000 non-null  float64
#  25  mode                            1000000 non-null  int64
#  26  mode_confidence                 1000000 non-null  float64
#  27  start_of_fade_out               1000000 non-null  float64
#  28  tempo                           1000000 non-null  float64
#  29  time_signature                  1000000 non-null  int64
#  30  time_signature_confidence       1000000 non-null  float64
#  31  track_id                        1000000 non-null  object
#  32  analyzer_version                0 non-null        float64
#  33  artist_7digitalid               1000000 non-null  int64
#  34  artist_familiarity              999815 non-null   float64
#  35  artist_hotttnesss               999988 non-null   float64
#  36  artist_id                       1000000 non-null  object
#  37  artist_latitude                 357492 non-null   float64
#  38  artist_location                 512871 non-null   object
#  39  artist_longitude                357492 non-null   float64
#  40  artist_mbid                     937429 non-null   object
#  41  artist_name                     1000000 non-null  object
#  42  artist_playmeid                 1000000 non-null  int64
#  43  genre                           0 non-null        float64
#  44  idx_artist_terms                1000000 non-null  int64
#  45  idx_similar_artists             1000000 non-null  int64
#  46  release                         999995 non-null   object
#  47  release_7digitalid              1000000 non-null  int64
#  48  song_hotttnesss                 581965 non-null   float64
#  49  song_id                         1000000 non-null  object
#  50  title                           999985 non-null   object
#  51  track_7digitalid                1000000 non-null  int64
#  52  idx_artist_mbtags               1000000 non-null  int64
#  53  year                            1000000 non-null  int64
# dtypes: float64(15), int64(30), object(9)
# memory usage: 412.0+ MB

# %%
# unique track count
print(f"Total number of unique track: {msd_df['track_id'].nunique()}")
# Out:
# Total number of unique track: 1000000

# %%
# unique artist count by artist_id
print(f"Total number of unique artists by artist_name: {msd_df['artist_id'].nunique()}")
# Out:
# Total number of unique artists by artist_name: 44745

# %%
# unique artist count by artist_name
print(f"Total number of unique artists by artist_name: {msd_df['artist_name'].nunique()}")
# Out:
# Total number of unique artists by artist_name: 72664

# %%
# unique artist_location count
print(f"Total number of unique locations of artist-origin: {msd_df['artist_location'].nunique()}")
# Out:
# Total number of unique locations of artist-origin: 5055

# %%
# unique album_of_release count by name
print(f"Total number of unique album of release by name: {msd_df['release'].nunique()}")
# Out:
# Total number of unique album of release by name: 149275

# %%
# unique album_of_release count by id
print(f"Total number of unique album of release by id: {msd_df['release_7digitalid'].nunique()}")
# Out:
# Total number of unique album of release by id: 177228

# %%
# Dowanloading the trimmed msd dataset
trimmed_msd = pd.read_csv('trimmed_msd.csv')
trimmed_msd.head()
# Out:
#    song_no   duration  end_of_fade_in  key  key_confidence  loudness  mode  \
# 0        1  252.05506           2.049   10           0.777    -4.829     0
# 1        2  156.55138           0.258    9           0.808   -10.555     1
# 2        3  138.97098           0.000    7           0.418    -2.060     1
# 3        4  145.05751           0.000    7           0.125    -4.654     1
# 4        5  514.29832           0.000    5           0.097    -7.806     0
#
#    mode_confidence  start_of_fade_out    tempo  ...    artist_location  \
# 0            0.688            236.635   87.002  ...                NaN
# 1            0.355            148.660  150.778  ...                NaN
# 2            0.566            138.971  177.768  ...  Glasgow, Scotland
# 3            0.451            138.687   87.433  ...                NaN
# 4            0.290            506.717  140.035  ...                NaN
#
#             artist_id artist_7digitalid  artist_playmeid       artist_name  \
# 0  ARYZTJS1187B98C555              4069            44895  Faster Pussy cat
# 1  ARMVN3U1187FB3A1EB            113480               -1  Karkkiautomaatti
# 2  ARGEKB01187FB50750             63531               -1    Hudson Mohawke
# 3  ARNWYLR1187B9B2F9C             65051            34000       Yerba Brava
# 4  AREQDTE1269FB37231            158279               -1        Der Mystic
#
#                                 release release_7digitalid  song_hotttnesss  \
# 0                 Monster Ballads X-Mas             633681         0.542899
# 1                           Karkuteillä             145266         0.299877
# 2                                Butter             625706         0.617871
# 3                               De Culo             199368              NaN
# 4  Rene Ablaze Presents Winter Sessions             209038              NaN
#
#                title  year
# 0       Silent Night  2003
# 1        Tanssi vaan  1995
# 2  No One Could Ever  2006
# 3      Si Vos Querés  2003
# 4   Tangle Of Aspens     0
#
# [5 rows x 25 columns]

# %%
# Basic information of trimmed_msd_df
trimmed_msd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   song_no                    1000000 non-null  int64
#  1   duration                   1000000 non-null  float64
#  2   end_of_fade_in             1000000 non-null  float64
#  3   key                        1000000 non-null  int64
#  4   key_confidence             1000000 non-null  float64
#  5   loudness                   1000000 non-null  float64
#  6   mode                       1000000 non-null  int64
#  7   mode_confidence            1000000 non-null  float64
#  8   start_of_fade_out          1000000 non-null  float64
#  9   tempo                      1000000 non-null  float64
#  10  time_signature             1000000 non-null  int64
#  11  time_signature_confidence  1000000 non-null  float64
#  12  track_id                   1000000 non-null  object
#  13  artist_familiarity         999815 non-null   float64
#  14  artist_hotttnesss          999988 non-null   float64
#  15  artist_location            512871 non-null   object
#  16  artist_id                  1000000 non-null  object
#  17  artist_7digitalid          1000000 non-null  int64
#  18  artist_playmeid            1000000 non-null  int64
#  19  artist_name                1000000 non-null  object
#  20  release                    999995 non-null   object
#  21  release_7digitalid         1000000 non-null  int64
#  22  song_hotttnesss            581965 non-null   float64
#  23  title                      999985 non-null   object
#  24  year                       1000000 non-null  int64
# dtypes: float64(11), int64(8), object(6)
# memory usage: 190.7+ MB

# %%
# Change datatype for year to date
# trimmed_msd['year'] = pd.to_datetime(trimmed_msd['year'], format='%Y')

# %%
# check for missing data
missing_data = trimmed_msd.isnull().sum()
missing_data
# Out:
# song_no                           0
# duration                          0
# end_of_fade_in                    0
# key                               0
# key_confidence                    0
# loudness                          0
# mode                              0
# mode_confidence                   0
# start_of_fade_out                 0
# tempo                             0
# time_signature                    0
# time_signature_confidence         0
# track_id                          0
# artist_familiarity              185
# artist_hotttnesss                12
# artist_location              487129
# artist_id                         0
# artist_7digitalid                 0
# artist_playmeid                   0
# artist_name                       0
# release                           5
# release_7digitalid                0
# song_hotttnesss              418035
# title                            15
# year                              0
# dtype: int64

# %%
# check for percentage of missing data
percent_missing = round((trimmed_msd.isnull().sum())/(trimmed_msd.isnull().count())*100,2)
percent_missing.sort_values(ascending=False).head(2)
# Out:
# artist_location    48.71
# song_hotttnesss    41.80
# dtype: float64

# %%
 # Drop artist_location column due to high percentage of missing data
trimmed_msd.drop(['artist_location'], axis=1, inplace=True)
trimmed_msd.head()
# Out:
#    song_no   duration  end_of_fade_in  key  key_confidence  loudness  mode  \
# 0        1  252.05506           2.049   10           0.777    -4.829     0
# 1        2  156.55138           0.258    9           0.808   -10.555     1
# 2        3  138.97098           0.000    7           0.418    -2.060     1
# 3        4  145.05751           0.000    7           0.125    -4.654     1
# 4        5  514.29832           0.000    5           0.097    -7.806     0
#
#    mode_confidence  start_of_fade_out    tempo  ...  artist_hotttnesss  \
# 0            0.688            236.635   87.002  ...           0.394032
# 1            0.355            148.660  150.778  ...           0.356992
# 2            0.566            138.971  177.768  ...           0.437504
# 3            0.451            138.687   87.433  ...           0.372349
# 4            0.290            506.717  140.035  ...           0.000000
#
#             artist_id artist_7digitalid  artist_playmeid       artist_name  \
# 0  ARYZTJS1187B98C555              4069            44895  Faster Pussy cat
# 1  ARMVN3U1187FB3A1EB            113480               -1  Karkkiautomaatti
# 2  ARGEKB01187FB50750             63531               -1    Hudson Mohawke
# 3  ARNWYLR1187B9B2F9C             65051            34000       Yerba Brava
# 4  AREQDTE1269FB37231            158279               -1        Der Mystic
#
#                                 release  release_7digitalid  song_hotttnesss  \
# 0                 Monster Ballads X-Mas              633681         0.542899
# 1                           Karkuteillä              145266         0.299877
# 2                                Butter              625706         0.617871
# 3                               De Culo              199368              NaN
# 4  Rene Ablaze Presents Winter Sessions              209038              NaN
#
#                title  year
# 0       Silent Night  2003
# 1        Tanssi vaan  1995
# 2  No One Could Ever  2006
# 3      Si Vos Querés  2003
# 4   Tangle Of Aspens     0
#
# [5 rows x 24 columns]

# %%
# Drop the observations with missing data
trimmed_msd.dropna(inplace=True)
trimmed_msd.head()
# Out:
#     song_no   duration  end_of_fade_in  key  key_confidence  loudness  mode  \
# 0         1  252.05506           2.049   10           0.777    -4.829     0
# 1         2  156.55138           0.258    9           0.808   -10.555     1
# 2         3  138.97098           0.000    7           0.418    -2.060     1
# 12       13  301.60934           0.000    1           0.450    -4.882     1
# 13       14  318.45832           0.502   10           0.764   -10.670     1
#
#     mode_confidence  start_of_fade_out    tempo  ...  artist_hotttnesss  \
# 0             0.688            236.635   87.002  ...           0.394032
# 1             0.355            148.660  150.778  ...           0.356992
# 2             0.566            138.971  177.768  ...           0.437504
# 12            0.520            291.405   85.340  ...           0.451579
# 13            0.627            306.265   67.567  ...           0.406985
#
#              artist_id artist_7digitalid  artist_playmeid       artist_name  \
# 0   ARYZTJS1187B98C555              4069            44895  Faster Pussy cat
# 1   ARMVN3U1187FB3A1EB            113480               -1  Karkkiautomaatti
# 2   ARGEKB01187FB50750             63531               -1    Hudson Mohawke
# 12  ARVIT0V1187B9A7CDE            165382               -1      Danny Diablo
# 13  AREMPER1187B9AEB42              5823               -1         Tiger Lou
#
#                              release  release_7digitalid  song_hotttnesss  \
# 0              Monster Ballads X-Mas              633681         0.542899
# 1                        Karkuteillä              145266         0.299877
# 2                             Butter              625706         0.617871
# 12  International Hardcore Superstar              620618         0.392009
# 13                         The Loyal              204414         0.463490
#
#                                   title  year
# 0                          Silent Night  2003
# 1                           Tanssi vaan  1995
# 2                     No One Could Ever  2006
# 12  Cold Beer feat. Prince Metropolitan     0
# 13                               Pilots  2005
#
# [5 rows x 24 columns]

# %%
# Basic information of trimmed_msd_df
trimmed_msd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 581909 entries, 0 to 999999
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   song_no                    581909 non-null  int64
#  1   duration                   581909 non-null  float64
#  2   end_of_fade_in             581909 non-null  float64
#  3   key                        581909 non-null  int64
#  4   key_confidence             581909 non-null  float64
#  5   loudness                   581909 non-null  float64
#  6   mode                       581909 non-null  int64
#  7   mode_confidence            581909 non-null  float64
#  8   start_of_fade_out          581909 non-null  float64
#  9   tempo                      581909 non-null  float64
#  10  time_signature             581909 non-null  int64
#  11  time_signature_confidence  581909 non-null  float64
#  12  track_id                   581909 non-null  object
#  13  artist_familiarity         581909 non-null  float64
#  14  artist_hotttnesss          581909 non-null  float64
#  15  artist_id                  581909 non-null  object
#  16  artist_7digitalid          581909 non-null  int64
#  17  artist_playmeid            581909 non-null  int64
#  18  artist_name                581909 non-null  object
#  19  release                    581909 non-null  object
#  20  release_7digitalid         581909 non-null  int64
#  21  song_hotttnesss            581909 non-null  float64
#  22  title                      581909 non-null  object
#  23  year                       581909 non-null  int64
# dtypes: float64(11), int64(8), object(5)
# memory usage: 111.0+ MB

# %%
# unique track count for the trimmed dataset
print(f"Total number of unique track: {trimmed_msd['track_id'].nunique()}")
# Out:
# Total number of unique track: 581909

# %%
# unique artist count for the trimmed dataset (by artist_id)
print(f"Total number of unique artists by artist_id: {trimmed_msd['artist_id'].nunique()}")
# Out:
# Total number of unique artists by artist_id: 36087

# %%
# unique artist count for the trimmed dataset (by artist_7digitalid)
print(f"Total number of unique artists by artist_7digitalid: {trimmed_msd['artist_7digitalid'].nunique()}")
# Out:
# Total number of unique artists by artist_7digitalid: 35598

# %%
# unique artist count for the trimmed dataset (by artist_playmeid)
print(f"Total number of unique artists by artist_playmeid: {trimmed_msd['artist_playmeid'].nunique()}")
# Out:
# Total number of unique artists by artist_playmeid: 12902

# %%
# unique artist count for the trimmed dataset (by artist_name)
print(f"Total number of unique artists by artist_name: {trimmed_msd['artist_name'].nunique()}")
# Out:
# Total number of unique artists by artist_name: 51751

# %%
# unique album_of_release count for the trimmed dataset (by name) 
print(f"Total number of unique album of release by name: {trimmed_msd['release'].nunique()}")
# Out:
# Total number of unique album of release by name: 108172

# %%
# unique companies_of_release count for the trimmed dataset (by id) 
print(f"Total number of unique album of release by name: {trimmed_msd['release_7digitalid'].nunique()}")
# Out:
# Total number of unique album of release by name: 125815

# %%
# Basic statistics for the clean dataset --- NOT YET. 
# Need further cleaning
trimmed_msd.describe()
# Out:
#               song_no       duration  end_of_fade_in            key  \
# count   581909.000000  581909.000000   581909.000000  581909.000000
# mean    500593.424517     247.472243        0.833324       5.316185
# std     288763.695996     118.622184        3.428424       3.592778
# min          1.000000       0.522000        0.000000       0.000000
# 25%     250400.000000     183.300770        0.000000       2.000000
# 50%     501264.000000     230.033830        0.194000       5.000000
# 75%     750648.000000     286.170980        0.426000       9.000000
# max    1000000.000000    3032.580770      991.359000      11.000000
#
#        key_confidence       loudness          mode  mode_confidence  \
# count   581909.000000  581909.000000  581909.00000    581909.000000
# mean         0.444725      -9.705346       0.66503         0.475587
# std          0.276527       4.967490       0.47198         0.192359
# min          0.000000     -55.751000       0.00000         0.000000
# 25%          0.216000     -12.147000       0.00000         0.360000
# 50%          0.464000      -8.594000       1.00000         0.486000
# 75%          0.654000      -6.139000       1.00000         0.606000
# max          1.000000       4.318000       1.00000         1.000000
#
#        start_of_fade_out          tempo  time_signature  \
# count      581909.000000  581909.000000   581909.000000
# mean          238.332774     124.694522        3.615234
# std           116.477629      34.969851        1.199780
# min             0.522000       0.000000        0.000000
# 25%           175.520000      98.505000        3.000000
# 50%           220.700000     122.069000        4.000000
# 75%           275.638000     145.604000        4.000000
# max          3030.622000     284.208000        7.000000
#
#        time_signature_confidence  artist_familiarity  artist_hotttnesss  \
# count              581909.000000       581909.000000      581909.000000
# mean                    0.519018            0.579859           0.398976
# std                     0.370371            0.130225           0.112635
# min                     0.000000            0.000000           0.000000
# 25%                     0.138000            0.504933           0.352843
# 50%                     0.560000            0.582700           0.399452
# 75%                     0.870000            0.659129           0.456170
# max                     1.000000            1.000000           1.082503
#
#        artist_7digitalid  artist_playmeid  release_7digitalid  \
# count      581909.000000    581909.000000       581909.000000
# mean       118581.057543     26480.363058       364752.068148
# std        140135.330716     47387.590191       236626.613808
# min            -1.000000        -1.000000           -1.000000
# 25%         14355.000000        -1.000000       163978.000000
# 50%         54572.000000       260.000000       323364.000000
# 75%        176113.000000     34211.000000       560107.000000
# max        817066.000000    242965.000000       823606.000000
#
#        song_hotttnesss           year
# count    581909.000000  581909.000000
# mean          0.356080    1190.441535
# std           0.234431     981.452971
# min           0.000000       0.000000
# 25%           0.215080       0.000000
# 50%           0.377532    1992.000000
# 75%           0.531985    2004.000000
# max           1.000000    2011.000000

# %%
# Check for outliers on target variable and key features ---- NOT CHECKED
# Finalize csv for clean data ---- NOT CHECKED
# Create another csv file: just for the artist_name and create artist_id ---- Checked
# Create another csv file: just for the release and create release_id ---- Checked

# %%
# Create a csv file for postgreSQL
trimmed_msd.drop(['song_no', 'artist_7digitalid', 'artist_playmeid', 'artist_playmeid', 'artist_id', 'release_7digitalid'], axis=1, inplace=True)
trimmed_msd
# Out:
#          duration  end_of_fade_in  key  key_confidence  loudness  mode  \
# 0       252.05506           2.049   10           0.777    -4.829     0
# 1       156.55138           0.258    9           0.808   -10.555     1
# 2       138.97098           0.000    7           0.418    -2.060     1
# 12      301.60934           0.000    1           0.450    -4.882     1
# 13      318.45832           0.502   10           0.764   -10.670     1
# ...           ...             ...  ...             ...       ...   ...
# 999990  228.41424           0.101   11           0.800    -4.843     0
# 999991  258.76853           0.287    4           0.247    -9.188     0
# 999992  241.21424           1.007    0           0.502    -5.303     1
# 999994  185.33832           0.000    1           0.040    -5.968     0
# 999999  295.07873           0.000    6           0.634    -5.801     1
#
#         mode_confidence  start_of_fade_out    tempo  time_signature  \
# 0                 0.688            236.635   87.002               4
# 1                 0.355            148.660  150.778               1
# 2                 0.566            138.971  177.768               4
# 12                0.520            291.405   85.340               5
# 13                0.627            306.265   67.567               3
# ...                 ...                ...      ...             ...
# 999990            0.690            208.451  130.155               4
# 999991            0.268            251.315   80.364               3
# 999992            0.457            238.539  148.354               4
# 999994            0.412            170.974  120.009               4
# 999999            0.445            292.182  164.037               4
#
#         time_signature_confidence            track_id  artist_familiarity  \
# 0                           0.940  TRMMMYQ128F932D901            0.649822
# 1                           0.000  TRMMMKD128F425225D            0.439604
# 2                           0.446  TRMMMRX128F93187D9            0.643681
# 12                          0.581  TRMMMCJ128F930BFF8            0.622005
# 13                          0.676  TRMMMBW128F4260CAE            0.621826
# ...                           ...                 ...                 ...
# 999990                      0.332  TRYYYYS12903D0605A            0.735147
# 999991                      0.493  TRYYYLF128E0789A44            0.586555
# 999992                      0.508  TRYYYZM128F428E804            0.592700
# 999994                      0.734  TRYYYNQ128F92E0292            0.699599
# 999999                      0.672  TRYYYVU12903CD01E3            0.552977
#
#         artist_hotttnesss                                        artist_name  \
# 0                0.394032                                   Faster Pussy cat
# 1                0.356992                                   Karkkiautomaatti
# 2                0.437504                                     Hudson Mohawke
# 12               0.451579                                       Danny Diablo
# 13               0.406985                                          Tiger Lou
# ...                   ...                                                ...
# 999990           0.471100               Taylor Hawkins & The Coattail Riders
# 999991           0.340153                                          Bah Samba
# 999992           0.429545                                            SKYCLAD
# 999994           0.392061  Killer Mike feat. Gangsta Pill and Nario of Gr...
# 999999           0.454869                                              Texta
#
#                                                   release  song_hotttnesss  \
# 0                                   Monster Ballads X-Mas         0.542899
# 1                                             Karkuteillä         0.299877
# 2                                                  Butter         0.617871
# 12                       International Hardcore Superstar         0.392009
# 13                                              The Loyal         0.463490
# ...                                                   ...              ...
# 999990                                           Way Down         0.753538
# 999991                                               Four         0.372530
# 999992                         No Daylights_ Nor Heeltaps         0.533155
# 999994  Messy Marv Presents: Draped Up and Chipped Out...         0.000000
# 999999                                         So Oder So         0.487950
#
#                                       title  year
# 0                              Silent Night  2003
# 1                               Tanssi vaan  1995
# 2                         No One Could Ever  2006
# 12      Cold Beer feat. Prince Metropolitan     0
# 13                                   Pilots  2005
# ...                                     ...   ...
# 999990                             Way Down  2010
# 999991                       So Many People  2002
# 999992                    Inequality Street  1996
# 999994                Down Fo' The Kick Doe     0
# 999999  Fernweh feat. Sektion Kuchikäschtli  2004
#
# [581909 rows x 19 columns]

# %%
# Create a csv file for postgreSQL
postgres_msd = trimmed_msd
postgres_msd
# Out:
#          duration  end_of_fade_in  key  key_confidence  loudness  mode  \
# 0       252.05506           2.049   10           0.777    -4.829     0
# 1       156.55138           0.258    9           0.808   -10.555     1
# 2       138.97098           0.000    7           0.418    -2.060     1
# 12      301.60934           0.000    1           0.450    -4.882     1
# 13      318.45832           0.502   10           0.764   -10.670     1
# ...           ...             ...  ...             ...       ...   ...
# 999990  228.41424           0.101   11           0.800    -4.843     0
# 999991  258.76853           0.287    4           0.247    -9.188     0
# 999992  241.21424           1.007    0           0.502    -5.303     1
# 999994  185.33832           0.000    1           0.040    -5.968     0
# 999999  295.07873           0.000    6           0.634    -5.801     1
#
#         mode_confidence  start_of_fade_out    tempo  time_signature  \
# 0                 0.688            236.635   87.002               4
# 1                 0.355            148.660  150.778               1
# 2                 0.566            138.971  177.768               4
# 12                0.520            291.405   85.340               5
# 13                0.627            306.265   67.567               3
# ...                 ...                ...      ...             ...
# 999990            0.690            208.451  130.155               4
# 999991            0.268            251.315   80.364               3
# 999992            0.457            238.539  148.354               4
# 999994            0.412            170.974  120.009               4
# 999999            0.445            292.182  164.037               4
#
#         time_signature_confidence            track_id  artist_familiarity  \
# 0                           0.940  TRMMMYQ128F932D901            0.649822
# 1                           0.000  TRMMMKD128F425225D            0.439604
# 2                           0.446  TRMMMRX128F93187D9            0.643681
# 12                          0.581  TRMMMCJ128F930BFF8            0.622005
# 13                          0.676  TRMMMBW128F4260CAE            0.621826
# ...                           ...                 ...                 ...
# 999990                      0.332  TRYYYYS12903D0605A            0.735147
# 999991                      0.493  TRYYYLF128E0789A44            0.586555
# 999992                      0.508  TRYYYZM128F428E804            0.592700
# 999994                      0.734  TRYYYNQ128F92E0292            0.699599
# 999999                      0.672  TRYYYVU12903CD01E3            0.552977
#
#         artist_hotttnesss                                        artist_name  \
# 0                0.394032                                   Faster Pussy cat
# 1                0.356992                                   Karkkiautomaatti
# 2                0.437504                                     Hudson Mohawke
# 12               0.451579                                       Danny Diablo
# 13               0.406985                                          Tiger Lou
# ...                   ...                                                ...
# 999990           0.471100               Taylor Hawkins & The Coattail Riders
# 999991           0.340153                                          Bah Samba
# 999992           0.429545                                            SKYCLAD
# 999994           0.392061  Killer Mike feat. Gangsta Pill and Nario of Gr...
# 999999           0.454869                                              Texta
#
#                                                   release  song_hotttnesss  \
# 0                                   Monster Ballads X-Mas         0.542899
# 1                                             Karkuteillä         0.299877
# 2                                                  Butter         0.617871
# 12                       International Hardcore Superstar         0.392009
# 13                                              The Loyal         0.463490
# ...                                                   ...              ...
# 999990                                           Way Down         0.753538
# 999991                                               Four         0.372530
# 999992                         No Daylights_ Nor Heeltaps         0.533155
# 999994  Messy Marv Presents: Draped Up and Chipped Out...         0.000000
# 999999                                         So Oder So         0.487950
#
#                                       title  year
# 0                              Silent Night  2003
# 1                               Tanssi vaan  1995
# 2                         No One Could Ever  2006
# 12      Cold Beer feat. Prince Metropolitan     0
# 13                                   Pilots  2005
# ...                                     ...   ...
# 999990                             Way Down  2010
# 999991                       So Many People  2002
# 999992                    Inequality Street  1996
# 999994                Down Fo' The Kick Doe     0
# 999999  Fernweh feat. Sektion Kuchikäschtli  2004
#
# [581909 rows x 19 columns]

# %%
# Create a csv file for postgreSQL
postgres_msd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 581909 entries, 0 to 999999
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   duration                   581909 non-null  float64
#  1   end_of_fade_in             581909 non-null  float64
#  2   key                        581909 non-null  int64
#  3   key_confidence             581909 non-null  float64
#  4   loudness                   581909 non-null  float64
#  5   mode                       581909 non-null  int64
#  6   mode_confidence            581909 non-null  float64
#  7   start_of_fade_out          581909 non-null  float64
#  8   tempo                      581909 non-null  float64
#  9   time_signature             581909 non-null  int64
#  10  time_signature_confidence  581909 non-null  float64
#  11  track_id                   581909 non-null  object
#  12  artist_familiarity         581909 non-null  float64
#  13  artist_hotttnesss          581909 non-null  float64
#  14  artist_name                581909 non-null  object
#  15  release                    581909 non-null  object
#  16  song_hotttnesss            581909 non-null  float64
#  17  title                      581909 non-null  object
#  18  year                       581909 non-null  int64
# dtypes: float64(11), int64(4), object(4)
# memory usage: 88.8+ MB

# %%
# Create a csv file for postgreSQL
postgres_msd.to_csv('postgres_msd.csv', index=False)

# %%
# Create a csv file: just for the artist_name with artist_newID
artist = trimmed_msd[['artist_name']].drop_duplicates()
artist
# Out:
#                                               artist_name
# 0                                        Faster Pussy cat
# 1                                        Karkkiautomaatti
# 2                                          Hudson Mohawke
# 12                                           Danny Diablo
# 13                                              Tiger Lou
# ...                                                   ...
# 999889  Ben Harney / Jennifer Holliday / Sheryl Lee Ra...
# 999916                                      Kim Hyun-Chul
# 999955                                    Pancho's Lament
# 999961  Ashley Tisdale/High School Musical Cast/Jemma ...
# 999994  Killer Mike feat. Gangsta Pill and Nario of Gr...
#
# [51751 rows x 1 columns]

# %%
# Create a csv file: just for the artist_name with artist_newID
artist['artist_newid'] = artist.reset_index().index + 1
artist
# Out:
#                                               artist_name  artist_newid
# 0                                        Faster Pussy cat             1
# 1                                        Karkkiautomaatti             2
# 2                                          Hudson Mohawke             3
# 12                                           Danny Diablo             4
# 13                                              Tiger Lou             5
# ...                                                   ...           ...
# 999889  Ben Harney / Jennifer Holliday / Sheryl Lee Ra...         51747
# 999916                                      Kim Hyun-Chul         51748
# 999955                                    Pancho's Lament         51749
# 999961  Ashley Tisdale/High School Musical Cast/Jemma ...         51750
# 999994  Killer Mike feat. Gangsta Pill and Nario of Gr...         51751
#
# [51751 rows x 2 columns]

# %%
# Create a csv file: just for the artist_name with artist_newID
artist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51751 entries, 0 to 999994
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_name   51751 non-null  object
#  1   artist_newid  51751 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 1.2+ MB

# %%
# Create artist.csv file with unique artist_name and artist_newID
artist.to_csv('artist.csv', index=False)

# %%
# Create a csv file: just for release with release_newID
release = trimmed_msd[['release']].drop_duplicates()
release
# Out:
#                                  release
# 0                  Monster Ballads X-Mas
# 1                            Karkuteillä
# 2                                 Butter
# 12      International Hardcore Superstar
# 13                             The Loyal
# ...                                  ...
# 999903               Dirty Laugh Remixes
# 999916            Kid's Pop 'Love Is...'
# 999926               Il Éait Une Fois...
# 999948                      Nachtexpress
# 999990                          Way Down
#
# [108172 rows x 1 columns]

# %%
# Create a csv file: just for release with release_newID
release['release_newid'] = release.reset_index().index + 1
release
# Out:
#                                  release  release_newid
# 0                  Monster Ballads X-Mas              1
# 1                            Karkuteillä              2
# 2                                 Butter              3
# 12      International Hardcore Superstar              4
# 13                             The Loyal              5
# ...                                  ...            ...
# 999903               Dirty Laugh Remixes         108168
# 999916            Kid's Pop 'Love Is...'         108169
# 999926               Il Éait Une Fois...         108170
# 999948                      Nachtexpress         108171
# 999990                          Way Down         108172
#
# [108172 rows x 2 columns]

# %%
# Create a csv file: just for release with release_newID
release.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 108172 entries, 0 to 999990
# Data columns (total 2 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   release        108172 non-null  object
#  1   release_newid  108172 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 2.5+ MB

# %%
# Create release.csv file with unique release and release_newID
release.to_csv('release.csv', index=False)

# %% [markdown]
# ### Connection to Postgres & SQL Query

# %%
# Create Connection to Database
engine =create_engine(f'postgresql://{username}:{password}@localhost:5432/msd_DB')
connection= engine.connect()

# %%
# Exporting artist table to postgres database; For Large Datasets use Chucksize
artist.to_sql('artist', con=connection, if_exists='replace', index=False, chunksize = 100 )

# %%
# Exporting release table to postgres database; For Large Datasets use Chucksize
release.to_sql('release', con=connection, if_exists='replace', index=False, chunksize = 100 )

# %%
# Exporting release table to postgres database; For Large Datasets use Chucksize
postgres_msd.to_sql('postgres_msd', con=connection, if_exists='replace', index=False, chunksize = 100 )

# %%
final_msd = pd.read_sql(
'select b.track_id, b.title, a.artist_newid, a.artist_name, b.artist_familiarity, b.artist_hotttnesss,\
c.release_newid, c.release, b.year, b.duration, b.end_of_fade_in, b.start_of_fade_out, b.tempo, b.loudness,\
b.key, b.key_confidence, b.mode, b.mode_confidence, b.time_signature, b.time_signature_confidence, b.song_hotttnesss \
from artist a join postgres_msd b \
on a.artist_name = b.artist_name \
join release c on b.release = c.release \
order by a.artist_newid',
connection)

final_msd.head(50)
# Out:
#               track_id                                              title  \
# 0   TRMMMYQ128F932D901                                       Silent Night
# 1   TRNSZOC128F425224E                                        Hei Johanna
# 2   TRABGDV128F4252252                                Toivon että huomaat
# 3   TRMMMKD128F425225D                                        Tanssi vaan
# 4   TRGBNVG128F425224D                                      Jää beibi jää
# 5   TRQGNIX128F425224F                              Aina vaan jaa jaa jaa
# 6   TRWUBYW128F4252258                                          Äl-oo-vee
# 7   TRBZRME128F425225E                                    Takaisin en tuu
# 8   TRFOSNY128F4252255                                Paina kaasua_ Honey
# 9   TRQRDVN128F425225F                                   Annathan anteeks
# 10  TRFXTTP128F4252259                               Ei oo ei oo toivokaa
# 11  TRMLAVN128F4252261                                    Yeah yeah Jenni
# 12  TRSJKBK128F4252256                   En kai koskaan löydä sitä oikeaa
# 13  TRQJXBW128F425225C                                    Taaskin turhaan
# 14  TRULYSN128F425225A                            Särkyneen sydämen twist
# 15  TRVVNZU128F4252251                       Kai vielä joskus muistat mua
# 16  TRKWTAK128F4252253                                   Hei okei mä meen
# 17  TRWAUOR128F9318794                                      Acoustic Lady
# 18  TRDQCHT128F931884B                            Allhot (feat. Nadsroic)
# 19  TRGFBFN128F931877C                                           ZOo00OOm
# 20  TRMZFDE128F93187A5                                           Rising 5
# 21  TRFDRLT128F93187BF               Just Decided (feat. Olivier Daysoul)
# 22  TRTTLBE128F9318835                                      Star Crackout
# 23  TRMMMRX128F93187D9                                  No One Could Ever
# 24  TRGMPUJ128F931871E                                          Gluetooth
# 25  TRXLDMD128F93187E9                                        Velvet Peel
# 26  TRPHCUJ128F931875F                                        Fruit Touch
# 27  TRZFTDP128F9318744                                                3.3
# 28  TRXBJIG128F9318822                                               FUSE
# 29  TRWJVDX128EF356E90                                      Riding Chrome
# 30  TRJECRX128F9318866                                        Black n Red
# 31  TRVLPQX128F9318707                                      Shower Melody
# 32  TREMHLW128F931872E              Joy Fantastic (feat. Olivier Daysoul)
# 33  TRVURZH128F93187B8                                     Twistclip Loop
# 34  TRZLVHB128F9318753                                              Trykk
# 35  TRHGWQQ128F930C00D                  Goodbye Farewell feat. Toby Morse
# 36  TRUQSRP128F930BFFD                                     Shot Gun Blast
# 37  TRKZVUF128F930BFF9                  Give Me A Chance feat. White Lion
# 38  TRECGMA128F930BFF6          Working Class featuring Natasha Nicholson
# 39  TRHUTVG128F930BFFB                                        Blood Money
# 40  TRKLBVH128F429C78E                                         Banged Out
# 41  TRLYFVN128F429C796  Satanic Shamrocks (Features Big left_ Danny Bo...
# 42  TRBLMUJ128F933F36D                                              Outro
# 43  TRYSBRP128F933F32F                             Intro / Blow Your Mind
# 44  TRHFAIK128F933F371                                       Private Hell
# 45  TRECEMQ128F429C79A                                    The Harsh Truth
# 46  TROYWEU128F930BFF2                                       Kill Em Dead
# 47  TREJOQD128F930C003  The Chosen Few feat. Sick Jacken_ White Trash ...
# 48  TRRFBRO128F930C00A  Queens Killaz feat. Prince Metropolitan and Cynic
# 49  TRVJQZX128F930BFEF  Sex And Violence feat. Everlast And Tim Armstrong
#
#     artist_newid       artist_name  artist_familiarity  artist_hotttnesss  \
# 0              1  Faster Pussy cat            0.649822           0.394032
# 1              2  Karkkiautomaatti            0.439604           0.356992
# 2              2  Karkkiautomaatti            0.439604           0.356992
# 3              2  Karkkiautomaatti            0.439604           0.356992
# 4              2  Karkkiautomaatti            0.439604           0.356992
# 5              2  Karkkiautomaatti            0.439604           0.356992
# 6              2  Karkkiautomaatti            0.439604           0.356992
# 7              2  Karkkiautomaatti            0.439604           0.356992
# 8              2  Karkkiautomaatti            0.439604           0.356992
# 9              2  Karkkiautomaatti            0.439604           0.356992
# 10             2  Karkkiautomaatti            0.439604           0.356992
# 11             2  Karkkiautomaatti            0.439604           0.356992
# 12             2  Karkkiautomaatti            0.439604           0.356992
# 13             2  Karkkiautomaatti            0.439604           0.356992
# 14             2  Karkkiautomaatti            0.439604           0.356992
# 15             2  Karkkiautomaatti            0.439604           0.356992
# 16             2  Karkkiautomaatti            0.439604           0.356992
# 17             3    Hudson Mohawke            0.643681           0.437504
# 18             3    Hudson Mohawke            0.643681           0.437504
# 19             3    Hudson Mohawke            0.643681           0.437504
# 20             3    Hudson Mohawke            0.643681           0.437504
# 21             3    Hudson Mohawke            0.643681           0.437504
# 22             3    Hudson Mohawke            0.643681           0.437504
# 23             3    Hudson Mohawke            0.643681           0.437504
# 24             3    Hudson Mohawke            0.643681           0.437504
# 25             3    Hudson Mohawke            0.643681           0.437504
# 26             3    Hudson Mohawke            0.643681           0.437504
# 27             3    Hudson Mohawke            0.643681           0.437504
# 28             3    Hudson Mohawke            0.643681           0.437504
# 29             3    Hudson Mohawke            0.643681           0.437504
# 30             3    Hudson Mohawke            0.643681           0.437504
# 31             3    Hudson Mohawke            0.643681           0.437504
# 32             3    Hudson Mohawke            0.643681           0.437504
# 33             3    Hudson Mohawke            0.643681           0.437504
# 34             3    Hudson Mohawke            0.643681           0.437504
# 35             4      Danny Diablo            0.622005           0.451579
# 36             4      Danny Diablo            0.622005           0.451579
# 37             4      Danny Diablo            0.622005           0.451579
# 38             4      Danny Diablo            0.622005           0.451579
# 39             4      Danny Diablo            0.622005           0.451579
# 40             4      Danny Diablo            0.622005           0.451579
# 41             4      Danny Diablo            0.622005           0.451579
# 42             4      Danny Diablo            0.622005           0.451579
# 43             4      Danny Diablo            0.622005           0.451579
# 44             4      Danny Diablo            0.622005           0.451579
# 45             4      Danny Diablo            0.622005           0.451579
# 46             4      Danny Diablo            0.622005           0.451579
# 47             4      Danny Diablo            0.622005           0.451579
# 48             4      Danny Diablo            0.622005           0.451579
# 49             4      Danny Diablo            0.622005           0.451579
#
#     release_newid                                            release  year  \
# 0               1                              Monster Ballads X-Mas  2003
# 1               2                                        Karkuteillä  1993
# 2               2                                        Karkuteillä  1995
# 3               2                                        Karkuteillä  1995
# 4               2                                        Karkuteillä  1995
# 5               2                                        Karkuteillä  1995
# 6               2                                        Karkuteillä  1995
# 7               2                                        Karkuteillä  1995
# 8               2                                        Karkuteillä  1995
# 9               2                                        Karkuteillä  1995
# 10              2                                        Karkuteillä  1995
# 11              2                                        Karkuteillä  1995
# 12              2                                        Karkuteillä  1993
# 13              2                                        Karkuteillä  1995
# 14              2                                        Karkuteillä  1995
# 15              2                                        Karkuteillä  1995
# 16              2                                        Karkuteillä  1995
# 17              3                                             Butter  2009
# 18              3                                             Butter  2009
# 19              3                                             Butter  2009
# 20              3                                             Butter  2009
# 21              3                                             Butter  2009
# 22              3                                             Butter  2008
# 23              3                                             Butter  2006
# 24              3                                             Butter  2009
# 25              3                                             Butter  2009
# 26              3                                             Butter  2009
# 27              3                                             Butter  2009
# 28              3                                             Butter  2009
# 29          29441                             Beat Dimensions Vol. 1     0
# 30              3                                             Butter  2009
# 31              3                                             Butter  2009
# 32              3                                             Butter  2009
# 33              3                                             Butter  2009
# 34              3                                             Butter  2009
# 35              4                   International Hardcore Superstar     0
# 36              4                   International Hardcore Superstar     0
# 37              4                   International Hardcore Superstar     0
# 38              4                   International Hardcore Superstar     0
# 39              4                   International Hardcore Superstar     0
# 40          39083                                    Thugcore 4 Life     0
# 41          39083                                    Thugcore 4 Life     0
# 42          19673  The Street CD Vol.1 (feat. Everlast_ Madball_ ...  2007
# 43          19673  The Street CD Vol.1 (feat. Everlast_ Madball_ ...     0
# 44          19673  The Street CD Vol.1 (feat. Everlast_ Madball_ ...  2007
# 45          39083                                    Thugcore 4 Life     0
# 46              4                   International Hardcore Superstar     0
# 47              4                   International Hardcore Superstar     0
# 48              4                   International Hardcore Superstar     0
# 49              4                   International Hardcore Superstar     0
#
#      duration  ...  start_of_fade_out    tempo  loudness  key  key_confidence  \
# 0   252.05506  ...            236.635   87.002    -4.829   10           0.777
# 1   137.79546  ...            129.469  178.517   -10.695    0           0.658
# 2    52.81914  ...             48.977  145.443   -10.803    2           0.047
# 3   156.55138  ...            148.660  150.778   -10.555    9           0.808
# 4   107.59791  ...             98.203  216.529   -11.612    7           0.081
# 5    88.84200  ...             82.965  208.529   -10.286    0           0.358
# 6    76.77342  ...             71.680  165.682   -10.648    9           0.613
# 7    80.61342  ...             72.284  110.905    -9.595    9           0.746
# 8   116.79302  ...            114.260  204.128   -10.992   11           0.503
# 9   117.78567  ...            110.875  176.341    -9.807    5           0.585
# 10   81.86730  ...             81.867  135.046   -11.335    7           0.723
# 11   92.52526  ...             92.525  167.544   -10.365    6           0.091
# 12  137.50812  ...            130.775  162.863   -11.759    7           1.000
# 13   57.91302  ...             54.253  196.141   -10.626    7           0.862
# 14  122.93179  ...            117.493  179.873    -9.530    9           0.000
# 15  111.59465  ...            106.121  139.706   -12.187    7           0.265
# 16   97.33179  ...             88.335  152.241   -11.477    2           0.640
# 17  126.69342  ...            121.940  107.686   -12.882    1           0.085
# 18  162.61179  ...            160.421   80.880    -4.795    1           0.077
# 19  162.06322  ...            155.818   74.977    -7.829   11           0.566
# 20  191.58159  ...            186.131   91.893    -4.016    6           0.319
# 21  230.03383  ...            213.438  132.190    -5.917    1           0.622
# 22  295.00036  ...            284.288  210.971   -13.004    9           0.225
# 23  138.97098  ...            138.971  177.768    -2.060    7           0.418
# 24  227.31710  ...            227.317   98.484    -8.403    1           0.891
# 25  136.09751  ...            121.585   87.914    -6.405    1           0.365
# 26  237.63546  ...            231.393   91.077    -5.147    0           0.344
# 27   95.03302  ...             95.033   64.019    -6.932    6           0.488
# 28  190.58893  ...            185.278   93.404    -5.986    9           0.256
# 29  226.16771  ...            215.551  108.757    -9.189    1           0.481
# 30  164.49261  ...            164.493  167.287    -3.561    6           0.493
# 31   81.18812  ...             81.188   30.408    -8.576    7           0.260
# 32  239.15057  ...            228.600   83.390    -4.493    1           0.421
# 33   82.99057  ...             82.991  104.360    -8.277    9           0.533
# 34  132.38812  ...            117.203   87.818    -5.537    6           0.149
# 35  237.71383  ...            229.570  130.049    -5.487    9           0.379
# 36  156.29016  ...            145.612  173.954    -3.187   11           0.012
# 37  261.87710  ...            261.877  153.834    -3.589    0           0.146
# 38  235.02322  ...            231.903   95.139    -3.059    0           0.143
# 39  295.78404  ...            293.152  166.057    -6.143    2           0.904
# 40  216.81587  ...            210.669   88.105    -5.559    4           0.138
# 41  319.81669  ...            315.170   81.252    -6.733    1           0.718
# 42   44.51220  ...             44.512   96.543   -14.341    4           0.078
# 43  184.73751  ...            184.738   86.737   -13.562   10           0.172
# 44  168.54159  ...            163.712   91.514   -19.389    9           0.394
# 45  306.36363  ...            297.912  120.437    -4.942    0           0.540
# 46  184.29342  ...            180.895   98.431    -3.548    3           0.767
# 47  291.00363  ...            288.682   72.533    -6.187    4           0.595
# 48  295.10485  ...            295.105  103.712    -3.326    6           0.323
# 49  206.57587  ...            203.668  140.065    -4.040    2           0.013
#
#     mode  mode_confidence  time_signature  time_signature_confidence  \
# 0      0            0.688               4                      0.940
# 1      1            0.541               1                      0.083
# 2      0            0.383               4                      0.000
# 3      1            0.355               1                      0.000
# 4      1            0.578               4                      0.382
# 5      1            0.467               1                      0.000
# 6      1            0.288               1                      0.000
# 7      0            0.416               4                      0.453
# 8      0            0.540               1                      0.000
# 9      1            0.504               1                      0.000
# 10     1            0.667               1                      0.000
# 11     1            0.406               1                      0.000
# 12     1            0.834               1                      0.000
# 13     1            0.716               1                      0.000
# 14     0            0.170               1                      0.000
# 15     1            0.476               4                      0.566
# 16     1            0.863               1                      0.000
# 17     0            0.189               7                      0.240
# 18     1            0.234               5                      1.000
# 19     1            0.407               4                      0.921
# 20     1            0.400               4                      0.681
# 21     1            0.724               3                      1.000
# 22     0            0.217               3                      0.775
# 23     1            0.566               4                      0.446
# 24     1            0.873               4                      0.700
# 25     0            0.329               4                      0.355
# 26     1            0.339               5                      1.000
# 27     1            0.526               1                      1.000
# 28     0            0.334               3                      1.000
# 29     1            0.327               4                      0.873
# 30     1            0.227               4                      1.000
# 31     0            0.459               4                      0.000
# 32     1            0.442               5                      0.951
# 33     1            0.403               3                      1.000
# 34     1            0.561               4                      1.000
# 35     1            0.445               4                      0.729
# 36     0            0.070               4                      0.535
# 37     0            0.249               4                      0.639
# 38     1            0.226               4                      0.000
# 39     0            0.741               4                      1.000
# 40     0            0.102               4                      0.659
# 41     1            0.521               4                      0.918
# 42     1            0.398               3                      0.551
# 43     0            0.423               4                      0.508
# 44     1            0.434               3                      0.310
# 45     1            0.606               4                      0.575
# 46     1            0.528               4                      0.685
# 47     1            0.337               4                      0.654
# 48     1            0.466               5                      0.973
# 49     1            0.287               4                      0.000
#
#     song_hotttnesss
# 0          0.542899
# 1          0.467366
# 2          0.377532
# 3          0.299877
# 4          0.367273
# 5          0.377532
# 6          0.340923
# 7          0.266955
# 8          0.355286
# 9          0.299877
# 10         0.266955
# 11         0.367273
# 12         0.355286
# 13         0.299877
# 14         0.299877
# 15         0.340923
# 16         0.340923
# 17         0.606373
# 18         0.400040
# 19         0.665484
# 20         0.617337
# 21         0.600970
# 22         0.607909
# 23         0.617871
# 24         0.655140
# 25         0.618048
# 26         0.605246
# 27         0.499446
# 28         0.698616
# 29         0.215080
# 30         0.590557
# 31         0.652849
# 32         0.661109
# 33         0.610847
# 34         0.608339
# 35         0.407233
# 36         0.407233
# 37         0.400040
# 38         0.413740
# 39         0.392009
# 40         0.476435
# 41         0.482122
# 42         0.434838
# 43         0.270776
# 44         0.304170
# 45         0.454193
# 46         0.439202
# 47         0.419674
# 48         0.392009
# 49         0.439202
#
# [50 rows x 21 columns]

# %%
final_msd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 581909 entries, 0 to 581908
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   track_id                   581909 non-null  object
#  1   title                      581909 non-null  object
#  2   artist_newid               581909 non-null  int64
#  3   artist_name                581909 non-null  object
#  4   artist_familiarity         581909 non-null  float64
#  5   artist_hotttnesss          581909 non-null  float64
#  6   release_newid              581909 non-null  int64
#  7   release                    581909 non-null  object
#  8   year                       581909 non-null  int64
#  9   duration                   581909 non-null  float64
#  10  end_of_fade_in             581909 non-null  float64
#  11  start_of_fade_out          581909 non-null  float64
#  12  tempo                      581909 non-null  float64
#  13  loudness                   581909 non-null  float64
#  14  key                        581909 non-null  int64
#  15  key_confidence             581909 non-null  float64
#  16  mode                       581909 non-null  int64
#  17  mode_confidence            581909 non-null  float64
#  18  time_signature             581909 non-null  int64
#  19  time_signature_confidence  581909 non-null  float64
#  20  song_hotttnesss            581909 non-null  float64
# dtypes: float64(11), int64(6), object(4)
# memory usage: 93.2+ MB

# %% [markdown]
# ### EDA for ML Model

# %%
# Creating a new feature called song_popularity based on whether song_hotness is above or below mean 
song_hotness_mean = trimmed_msd['song_hotttnesss'].mean()
song_hotness_mean
# Out:
# 0.356080330963952

# %%
# Creating a new feature called song_popularity based on whether song_hotness is above or below mean 
trimmed_msd['song_popularity'] = trimmed_msd['song_hotttnesss']
trimmed_msd.head()
# Out:
#      duration  end_of_fade_in  key  key_confidence  loudness  mode  \
# 0   252.05506           2.049   10           0.777    -4.829     0
# 1   156.55138           0.258    9           0.808   -10.555     1
# 2   138.97098           0.000    7           0.418    -2.060     1
# 12  301.60934           0.000    1           0.450    -4.882     1
# 13  318.45832           0.502   10           0.764   -10.670     1
#
#     mode_confidence  start_of_fade_out    tempo  time_signature  \
# 0             0.688            236.635   87.002               4
# 1             0.355            148.660  150.778               1
# 2             0.566            138.971  177.768               4
# 12            0.520            291.405   85.340               5
# 13            0.627            306.265   67.567               3
#
#     time_signature_confidence            track_id  artist_familiarity  \
# 0                       0.940  TRMMMYQ128F932D901            0.649822
# 1                       0.000  TRMMMKD128F425225D            0.439604
# 2                       0.446  TRMMMRX128F93187D9            0.643681
# 12                      0.581  TRMMMCJ128F930BFF8            0.622005
# 13                      0.676  TRMMMBW128F4260CAE            0.621826
#
#     artist_hotttnesss       artist_name                           release  \
# 0            0.394032  Faster Pussy cat             Monster Ballads X-Mas
# 1            0.356992  Karkkiautomaatti                       Karkuteillä
# 2            0.437504    Hudson Mohawke                            Butter
# 12           0.451579      Danny Diablo  International Hardcore Superstar
# 13           0.406985         Tiger Lou                         The Loyal
#
#     song_hotttnesss                                title  year  \
# 0          0.542899                         Silent Night  2003
# 1          0.299877                          Tanssi vaan  1995
# 2          0.617871                    No One Could Ever  2006
# 12         0.392009  Cold Beer feat. Prince Metropolitan     0
# 13         0.463490                               Pilots  2005
#
#     song_popularity
# 0          0.542899
# 1          0.299877
# 2          0.617871
# 12         0.392009
# 13         0.463490

# %%
# Creating a new feature called song_popularity based on whether song_hotness is above or below mean 
trimmed_msd['song_popularity'] = trimmed_msd['song_hotttnesss'].apply(lambda x: 1 if x > song_hotness_mean else 0)
trimmed_msd.head()
# Out:
#      duration  end_of_fade_in  key  key_confidence  loudness  mode  \
# 0   252.05506           2.049   10           0.777    -4.829     0
# 1   156.55138           0.258    9           0.808   -10.555     1
# 2   138.97098           0.000    7           0.418    -2.060     1
# 12  301.60934           0.000    1           0.450    -4.882     1
# 13  318.45832           0.502   10           0.764   -10.670     1
#
#     mode_confidence  start_of_fade_out    tempo  time_signature  \
# 0             0.688            236.635   87.002               4
# 1             0.355            148.660  150.778               1
# 2             0.566            138.971  177.768               4
# 12            0.520            291.405   85.340               5
# 13            0.627            306.265   67.567               3
#
#     time_signature_confidence            track_id  artist_familiarity  \
# 0                       0.940  TRMMMYQ128F932D901            0.649822
# 1                       0.000  TRMMMKD128F425225D            0.439604
# 2                       0.446  TRMMMRX128F93187D9            0.643681
# 12                      0.581  TRMMMCJ128F930BFF8            0.622005
# 13                      0.676  TRMMMBW128F4260CAE            0.621826
#
#     artist_hotttnesss       artist_name                           release  \
# 0            0.394032  Faster Pussy cat             Monster Ballads X-Mas
# 1            0.356992  Karkkiautomaatti                       Karkuteillä
# 2            0.437504    Hudson Mohawke                            Butter
# 12           0.451579      Danny Diablo  International Hardcore Superstar
# 13           0.406985         Tiger Lou                         The Loyal
#
#     song_hotttnesss                                title  year  \
# 0          0.542899                         Silent Night  2003
# 1          0.299877                          Tanssi vaan  1995
# 2          0.617871                    No One Could Ever  2006
# 12         0.392009  Cold Beer feat. Prince Metropolitan     0
# 13         0.463490                               Pilots  2005
#
#     song_popularity
# 0                 1
# 1                 0
# 2                 1
# 12                1
# 13                1

# %%
trimmed_msd['song_popularity'].value_counts()
# Out:
# 1    311031
# 0    270878
# Name: song_popularity, dtype: int64

# %%
X = trimmed_msd[['duration', 'end_of_fade_in', 'key', 'loudness', 'mode', 'start_of_fade_out', 'tempo', 'time_signature', 'artist_familiarity', 'artist_hotttnesss', 'year']]
y = trimmed_msd['song_popularity']

# %%
X
# Out:
#          duration  end_of_fade_in  key  loudness  mode  start_of_fade_out  \
# 0       252.05506           2.049   10    -4.829     0            236.635
# 1       156.55138           0.258    9   -10.555     1            148.660
# 2       138.97098           0.000    7    -2.060     1            138.971
# 12      301.60934           0.000    1    -4.882     1            291.405
# 13      318.45832           0.502   10   -10.670     1            306.265
# ...           ...             ...  ...       ...   ...                ...
# 999990  228.41424           0.101   11    -4.843     0            208.451
# 999991  258.76853           0.287    4    -9.188     0            251.315
# 999992  241.21424           1.007    0    -5.303     1            238.539
# 999994  185.33832           0.000    1    -5.968     0            170.974
# 999999  295.07873           0.000    6    -5.801     1            292.182
#
#           tempo  time_signature  artist_familiarity  artist_hotttnesss  year
# 0        87.002               4            0.649822           0.394032  2003
# 1       150.778               1            0.439604           0.356992  1995
# 2       177.768               4            0.643681           0.437504  2006
# 12       85.340               5            0.622005           0.451579     0
# 13       67.567               3            0.621826           0.406985  2005
# ...         ...             ...                 ...                ...   ...
# 999990  130.155               4            0.735147           0.471100  2010
# 999991   80.364               3            0.586555           0.340153  2002
# 999992  148.354               4            0.592700           0.429545  1996
# 999994  120.009               4            0.699599           0.392061     0
# 999999  164.037               4            0.552977           0.454869  2004
#
# [581909 rows x 11 columns]

# %%
y
# Out:
# 0         1
# 1         0
# 2         1
# 12        1
# 13        1
#          ..
# 999990    1
# 999991    1
# 999992    1
# 999994    0
# 999999    1
# Name: song_popularity, Length: 581909, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
# shift+tab and simply copy
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# importing decision tree classifier
from sklearn.tree import DecisionTreeClassifier

# %%
#Creating instance "dtree" of the classifier 
dtree = DecisionTreeClassifier(criterion='entropy')

# %%
#fitting to the training data, the default parameters are fine at the moment!
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
# doing predictions 
dtree_pred = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print(classification_report(y_test, dtree_pred))
print(confusion_matrix(y_test, dtree_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.69      0.69     89287
#            1       0.73      0.73      0.73    102743
#
#     accuracy                           0.71    192030
#    macro avg       0.71      0.71      0.71    192030
# weighted avg       0.71      0.71      0.71    192030
#
# [[61214 28073]
#  [27991 74752]]

# %% [markdown]
# ## Matrix for 10 Features
#
#
#
# precision    recall  f1-score   support
#
#            0       0.66      0.66      0.66     89287
#            1       0.70      0.70      0.70    102743
#
#     accuracy                           0.68    192030
#    macro avg       0.68      0.68      0.68    192030
# weighted avg       0.68      0.68      0.68    192030
#
# [[58840 30447]
#  [30905 71838]]

# %%
# connection.close()
